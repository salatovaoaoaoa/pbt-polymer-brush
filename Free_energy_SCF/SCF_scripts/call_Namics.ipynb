# %%
# !namics 'annealing_brush_temp.in'
# Out:
# Problem nr 1 out of 1
# The program is compiled for the use of 'long double' while 'overflow_protection' is not requested for;
# 1. Turn on 'overflow_protection'.
# 2. Compile progrem without the #define 'LongReal' in namics.h.
# 5 iterations to find alphabulk values.
# NEWTON has been notified.
# Your guess:it =  0  E = 3.777315e+00 |g| = 1.520640e+01 alpha = 1.000000e+00
# hessian scaling: 3.73139
# it =  1  E = 3.310553e+00 |g| = 1.284854e+01 alpha = 1.065762e-01
# it =  2  E = 2.213537e+00 |g| = 1.413396e+01 alpha = 2.474343e-01
# it =  3  E = 1.405393e+01 |g| = 1.598500e+01 alpha = 7.522388e-03
# it =  4  E = 4.749659e+00 |g| = 1.525501e+01 alpha = 6.464862e-02
# it =  5  E = 4.077283e+00 |g| = 1.478881e+01 alpha = 8.269558e-02
# it =  6  E = 1.878533e+01 |g| = 1.493154e+01 alpha = 3.638314e-03
# it =  7  E = 1.003095e+01 |g| = 1.370090e+01 alpha = 1.081041e-02
# it =  8  E = 5.757544e+00 |g| = 1.318594e+01 alpha = 2.931901e-02
# ...

# %%
# !namics 'flat_anion_brush_temp.in'
# Out:
# Problem nr 1 out of 1
# The program is compiled for the use of 'long double' while 'overflow_protection' is not requested for;
# 1. Turn on 'overflow_protection'.
# 2. Compile progrem without the #define 'LongReal' in namics.h.
# ...
# NEWTON has been notified.
# Your guess:it =  0  E = 3.784245e+00 |g| = 1.525901e+01 alpha = 1.000000e+00
# hessian scaling: 3.72239
# it =  1  E = 3.322335e+00 |g| = 1.293741e+01 alpha = 1.065535e-01
# it =  2  E = 2.237128e+00 |g| = 1.429741e+01 alpha = 2.450697e-01
# it =  3  E = 1.047426e+01 |g| = 1.606411e+01 alpha = 1.361350e-02
# it =  4  E = 4.574874e+00 |g| = 1.526219e+01 alpha = 6.968336e-02
# it =  5  E = 4.180486e+00 |g| = 1.489600e+01 alpha = 7.922926e-02
# it =  6  E = 2.525507e+01 |g| = 1.506486e+01 alpha = 2.031716e-03
# it =  7  E = 1.851937e+01 |g| = 1.393371e+01 alpha = 3.226510e-03
# it =  8  E = 6.254548e+00 |g| = 1.344003e+01 alpha = 2.533073e-02
# it =  9  E = 4.417537e+00 |g| = 1.268966e+01 alpha = 4.477797e-02
# ...
